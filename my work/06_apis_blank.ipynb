# %%
## imports
import pandas as pd
import numpy as np
import re
import requests
import yaml


## repeated printouts
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# # 1. Example 1: no credentials; no wrapper
#
# Site: National Assessment of Education Progress (NAEP)
#
# Documentation: https://www.nationsreportcard.gov/api_documentation.aspx
#
# Base link: https://www.nationsreportcard.gov/DataService/GetAdhocData.aspx

# %% [markdown]
# ## 1.1 Query to pull some data

# %%
## using their example query of 2011 writing scores separated by gender
## based on here - https://stackoverflow.com/questions/40836749/pythonic-way-of-writing-a-single-line-long-string
## using the ( ) syntax to formulate a long
## string without linebreaks added
example_naep_query = (
'https://www.nationsreportcard.gov/'
'Dataservice/GetAdhocData.aspx?'
'type=data&subject=writing&grade=8&'
'subscale=WRIRP&variable=GENDER&jurisdiction=NP&stattype=MN:MN&Year=2011')


example_naep_query
# Out:
# 'https://www.nationsreportcard.gov/Dataservice/GetAdhocData.aspx?type=data&subject=writing&grade=8&subscale=WRIRP&variable=GENDER&jurisdiction=NP&stattype=MN:MN&Year=2011'

# %%
## use requests to call the api
naep_resp = requests.get(example_naep_query)
naep_resp
print(type(naep_resp))

## get the json contents of the response 
## here, we're assuming valid response
naep_resp_j = naep_resp.json()
naep_resp_j

## with result, turn it into a dataframe
naep_resp_d = pd.DataFrame(naep_resp_j['result'])
naep_resp_d
# Out:
# <Response [200]>
# <class 'requests.models.Response'>
# {'status': 200,
#  'result': [{'year': 2011,
#    'sample': 'R3',
#    'yearSampleLabel': '2011',
#    'Cohort': 2,
#    'CohortLabel': 'Grade 8',
#    'stattype': 'MN:MN',
#    'subject': 'WRI',
#    'grade': 8,
#    'scale': 'WRIRP',
#    'jurisdiction': 'NP',
#    'jurisLabel': 'National public',
#    'variable': 'GENDER',
#    'variableLabel': 'Gender',
#    'varValue': '1',
#    'varValueLabel': 'Male',
#    'value': 139.099504632971,
#    'isStatDisplayable': 1,
#    'errorFlag': 0},
#   {'year': 2011,
#    'sample': 'R3',
#    'yearSampleLabel': '2011',
#    'Cohort': 2,
#    'CohortLabel': 'Grade 8',
#    'stattype': 'MN:MN',
#    'subject': 'WRI',
#    'grade': 8,
#    'scale': 'WRIRP',
#    'jurisdiction': 'NP',
#    'jurisLabel': 'National public',
#    'variable': 'GENDER',
#    'variableLabel': 'Gender',
#    'varValue': '2',
#    'varValueLabel': 'Female',
#    'value': 158.567104984955,
#    'isStatDisplayable': 1,
#    'errorFlag': 0}]}
#    year sample yearSampleLabel  Cohort CohortLabel stattype subject  grade  \
# 0  2011     R3            2011       2     Grade 8    MN:MN     WRI      8
# 1  2011     R3            2011       2     Grade 8    MN:MN     WRI      8
#
#    scale jurisdiction       jurisLabel variable variableLabel varValue  \
# 0  WRIRP           NP  National public   GENDER        Gender        1
# 1  WRIRP           NP  National public   GENDER        Gender        2
#
#   varValueLabel       value  isStatDisplayable  errorFlag
# 0          Male  139.099505                  1          0
# 1        Female  158.567105                  1          0

# %% [markdown]
# ## 1.2 What happens if there's an error in our query?

# %%
## here's a query that from the documentation we know
## won't work since i modified year to 2025 which doesnt
## exist in the data
wrong_naep_query = (
'https://www.nationsreportcard.gov/'
'Dataservice/GetAdhocData.aspx?'
'type=data&subject=writing&grade=8&'
'subscale=WRIRP&variable=GENDER&jurisdiction=NP&stattype=MN:MN&Year=2025')

wrong_naep_query
# Out:
# 'https://www.nationsreportcard.gov/Dataservice/GetAdhocData.aspx?type=data&subject=writing&grade=8&subscale=WRIRP&variable=GENDER&jurisdiction=NP&stattype=MN:MN&Year=2025'

# %%
## use requests to call the api
naep_wrong_resp = requests.get(wrong_naep_query)
naep_wrong_resp

# %%
## in the case of this particular api,
## the call returns some response but
## when we try to extract the json containing
## status or results, we get in an error
#naep_wrong_resp.json() # uncomment to see error

# %% [markdown]
# ### 1.2.2 More all-purpose way of allowing remainder of calls to run: try, except

# %%
## putting it in a try; except as general error catching
try:
    results = naep_wrong_resp.json()['result']
except Exception as e:
    print('Failed to get result from API due to error:')
    print(e) # or just: pass

# %% [markdown]
# ### 1.2.3 Can usually also find more targeted way but that varies more across APIs

# %%
## if we wanted do more specific error catching,
## see that the status == 400 actually appears here
## so could write if else along those lines
naep_wrong_resp.text
naep_resp.text

if "System.Exception" in naep_wrong_resp.text:
    print("NAEP results not found")

# %% [markdown]
# ## Activity 1: writing a function to make multiple, sequential calls
#
# - Say we want to pull the data for grades 4, 8, and 12
# - How can we write a function that iterates over a list of those grades and pulls the data for each grade?
#
# **Note**: an ideal function would have arguments for each parameter in the API like subject, subscale, etc. Here we can leave those other parts constant

# %%
# your code here
# your code here
def doGrade(grade):
    link = 'https://www.nationsreportcard.gov/''Dataservice/GetAdhocData.aspx?''type=data&subject=writing&grade=' + str(grade) + '&''subscale=WRIRP&variable=GENDER&jurisdiction=NP&stattype=MN:MN&Year=2011'
    naep_resp1 = requests.get(link)
    print(naep_resp1)
    print(type(naep_resp1))
    try:
        results = naep_resp1.json()['result']
        return results
    except Exception as e:
        print('Failed to get result from API due to error:')
        print(e) # or just: pass
doGrade(4)
doGrade(8)
doGrade(12)
# Out:
# <Response [200]>
# <class 'requests.models.Response'>
# Failed to get result from API due to error:
# Invalid control character at: line 1 column 289 (char 288)
# <Response [200]>
# <class 'requests.models.Response'>
# [{'year': 2011,
#   'sample': 'R3',
#   'yearSampleLabel': '2011',
#   'Cohort': 2,
#   'CohortLabel': 'Grade 8',
#   'stattype': 'MN:MN',
#   'subject': 'WRI',
#   'grade': 8,
#   'scale': 'WRIRP',
#   'jurisdiction': 'NP',
#   'jurisLabel': 'National public',
#   'variable': 'GENDER',
#   'variableLabel': 'Gender',
#   'varValue': '1',
#   'varValueLabel': 'Male',
#   'value': 139.099504632971,
#   'isStatDisplayable': 1,
#   'errorFlag': 0},
#  {'year': 2011,
#   'sample': 'R3',
#   'yearSampleLabel': '2011',
#   'Cohort': 2,
#   'CohortLabel': 'Grade 8',
#   'stattype': 'MN:MN',
#   'subject': 'WRI',
#   'grade': 8,
#   'scale': 'WRIRP',
#   'jurisdiction': 'NP',
#   'jurisLabel': 'National public',
#   'variable': 'GENDER',
#   'variableLabel': 'Gender',
#   'varValue': '2',
#   'varValueLabel': 'Female',
#   'value': 158.567104984955,
#   'isStatDisplayable': 1,
#   'errorFlag': 0}]
# <Response [200]>
# <class 'requests.models.Response'>
# [{'year': 2011,
#   'sample': 'R3',
#   'yearSampleLabel': '2011',
#   'Cohort': 3,
#   'CohortLabel': 'Grade 12',
#   'stattype': 'MN:MN',
#   'subject': 'WRI',
#   'grade': 12,
#   'scale': 'WRIRP',
#   'jurisdiction': 'NP',
#   'jurisLabel': 'National public',
#   'variable': 'GENDER',
#   'variableLabel': 'Gender',
#   'varValue': '1',
#   'varValueLabel': 'Male',
#   'value': 141.256977963264,
#   'isStatDisplayable': 1,
#   'errorFlag': 0},
#  {'year': 2011,
#   'sample': 'R3',
#   'yearSampleLabel': '2011',
#   'Cohort': 3,
#   'CohortLabel': 'Grade 12',
#   'stattype': 'MN:MN',
#   'subject': 'WRI',
#   'grade': 12,
#   'scale': 'WRIRP',
#   'jurisdiction': 'NP',
#   'jurisLabel': 'National public',
#   'variable': 'GENDER',
#   'variableLabel': 'Gender',
#   'varValue': '2',
#   'varValueLabel': 'Female',
#   'value': 155.385916780351,
#   'isStatDisplayable': 1,
#   'errorFlag': 0}]

# %% [markdown]
# # 2. Example 2: needs credentials; no wrapper

# %% [markdown]
# Create an account here: https://www.yelp.com/developers/v3/manage_app

# %%
## get the key
API_KEY = "hDmREkKL9dz5eDOpQ6AKykDFKpZDlfqKoRP6N9R6e4N3-35RRIcgoF7-HKfZbDiEOm6gPZueckvz6nE8o1bEEVdU2Qpo0M_SNvQ5IcEGiJGmCJ7PMTw5x0JY7q4zZnYx"

# %%
## use documentation to define what to search
## doc: https://www.yelp.com/developers/documentation/v3/business_search
## write the query 
base_url = "https://api.yelp.com/v3/businesses/search?"
my_name = "restaurants"
my_location = "Boulder,CO,80303"
yelp_genquery = ('{base_url}'
                'term={name}'
                '&location={loc}').format(base_url = base_url,
                name = my_name,
                loc = my_location)

## use requests to call the API; here, we're
## passing it our credentials (structure varies
## by API and telling it to only return 10 results
## (max is 50 at once)
header = {'Authorization': f"Bearer {API_KEY}"}
yelp_genresp = requests.get(yelp_genquery, headers = header)
yelp_genresp

## then, look at structure of response
yelp_genjson = yelp_genresp.json()
# Out:
# <Response [200]>

# %%
## example business
yelp_genjson['businesses'][0]

## more automatic way of summarizing but things end up in lists
## within columns for things like categories
yelp_gendf = pd.DataFrame(yelp_genjson['businesses'])
yelp_gendf.head()
# Out:
# {'id': 'GygGWp-ODQcqnizOxr5VLg',
#  'alias': 'postino-boulder-boulder-2',
#  'name': 'Postino Boulder',
#  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/qs98C86gzRNDcJ8I7GqemA/o.jpg',
#  'is_closed': False,
#  'url': 'https://www.yelp.com/biz/postino-boulder-boulder-2?adjust_creative=cVBMMgOprygzhvGPlqJb5w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=cVBMMgOprygzhvGPlqJb5w',
#  'review_count': 119,
#  'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#   {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#   {'alias': 'catering', 'title': 'Caterers'}],
#  'rating': 4.7,
#  'coordinates': {'latitude': 40.01843, 'longitude': -105.27622},
#  'transactions': ['delivery', 'pickup'],
#  'location': {'address1': '1468 Pearl St',
#   'address2': 'Ste 110',
#   'address3': '',
#   'city': 'Boulder',
#   'zip_code': '80302',
#   'country': 'US',
#   'state': 'CO',
#   'display_address': ['1468 Pearl St', 'Ste 110', 'Boulder, CO 80302']},
#  'phone': '+13032853755',
#  'display_phone': '(303) 285-3755',
#  'distance': 8365.566524163489,
#  'attributes': {'business_temp_closed': None,
#   'menu_url': 'https://www.postinowinecafe.com/menu',
#   'open24_hours': None,
#   'waitlist_reservation': None}}
#                        id                                          alias  \
# 0  GygGWp-ODQcqnizOxr5VLg                      postino-boulder-boulder-2
# 1  PPFY_lw5KkPNfJwpI8dbbw                       king-dumpling-louisville
# 2  _8vtC2Jo29HZwyNhQ3PWrg                    blackbelly-market-boulder-2
# 3  mbrY3doqkZoNDjzLFfXnyQ  parma-trattoria-and-mozzarella-bar-louisville
# 4  1LMe5UqMS2ei_ubt46FbNA                    the-buff-restaurant-boulder
#
#                                name  \
# 0                   Postino Boulder
# 1                     King Dumpling
# 2                 Blackbelly Market
# 3  Parma Trattoria & Mozzarella Bar
# 4               The Buff Restaurant
#
#                                            image_url  is_closed  \
# 0  https://s3-media2.fl.yelpcdn.com/bphoto/qs98C8...      False
# 1  https://s3-media3.fl.yelpcdn.com/bphoto/BSjNo3...      False
# 2  https://s3-media2.fl.yelpcdn.com/bphoto/R0Fcme...      False
# 3  https://s3-media4.fl.yelpcdn.com/bphoto/iFSEUe...      False
# 4  https://s3-media4.fl.yelpcdn.com/bphoto/Hll4hZ...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/postino-boulder-bould...           119
# 1  https://www.yelp.com/biz/king-dumpling-louisvi...            14
# 2  https://www.yelp.com/biz/blackbelly-market-bou...           635
# 3  https://www.yelp.com/biz/parma-trattoria-and-m...          1014
# 4  https://www.yelp.com/biz/the-buff-restaurant-b...          1864
#
#                                           categories  rating  \
# 0  [{'alias': 'wine_bars', 'title': 'Wine Bars'},...     4.7
# 1  [{'alias': 'chinese', 'title': 'Chinese'}, {'a...     4.8
# 2  [{'alias': 'butcher', 'title': 'Butcher'}, {'a...     4.2
# 3  [{'alias': 'italian', 'title': 'Italian'}, {'a...     4.4
# 4  [{'alias': 'breakfast_brunch', 'title': 'Break...     4.4
#
#                                          coordinates  \
# 0    {'latitude': 40.01843, 'longitude': -105.27622}
# 1  {'latitude': 39.96548077308674, 'longitude': -...
# 2  {'latitude': 40.015306, 'longitude': -105.227417}
# 3  {'latitude': 39.961607, 'longitude': -105.167235}
# 4  {'latitude': 40.017245, 'longitude': -105.2602...
#
#                transactions  \
# 0        [delivery, pickup]
# 1  [restaurant_reservation]
# 2                [delivery]
# 3        [delivery, pickup]
# 4                [delivery]
#
#                                             location         phone  \
# 0  {'address1': '1468 Pearl St', 'address2': 'Ste...  +13032853755
# 1  {'address1': '316 McCaslin Blvd', 'address2': ...  +17207285903
# 2  {'address1': '1606 Conestoga St', 'address2': ...  +13032471000
# 3  {'address1': '1132 W Dillon Rd', 'address2': '...  +13032842741
# 4  {'address1': '2600 Canyon Blvd', 'address2': '...  +13034429150
#
#     display_phone     distance  \
# 0  (303) 285-3755  8365.566524
# 1  (720) 728-5903  3773.646571
# 2  (303) 247-1000  5782.037744
# 3  (303) 284-2741  3319.287565
# 4  (303) 442-9150  7335.257038
#
#                                           attributes price
# 0  {'business_temp_closed': None, 'menu_url': 'ht...   NaN
# 1  {'business_temp_closed': None, 'menu_url': Non...   NaN
# 2  {'business_temp_closed': None, 'menu_url': 'ht...    $$
# 3  {'business_temp_closed': None, 'menu_url': 'ht...    $$
# 4  {'business_temp_closed': None, 'menu_url': Non...    $$

# %%
## more data-specific way of summarizing
## we're doing a simple approach and just retaining
## cols that have a simple str structure
## if doing for real, would want to extract things
def clean_yelp_json(one_biz):

    ## restrict to str cols
    d_str = {key:value for key, value in one_biz.items()
             if type(value) == str}
    
    df_str = pd.DataFrame(d_str, index = [d_str['id']])
    return(df_str)

yelp_stronly = [clean_yelp_json(one_b) for one_b in yelp_genjson['businesses']]
yelp_stronly_df = pd.concat(yelp_stronly)

yelp_stronly_df.head(7)
# Out:
#                                             id  \
# GygGWp-ODQcqnizOxr5VLg  GygGWp-ODQcqnizOxr5VLg
# PPFY_lw5KkPNfJwpI8dbbw  PPFY_lw5KkPNfJwpI8dbbw
# _8vtC2Jo29HZwyNhQ3PWrg  _8vtC2Jo29HZwyNhQ3PWrg
# mbrY3doqkZoNDjzLFfXnyQ  mbrY3doqkZoNDjzLFfXnyQ
# 1LMe5UqMS2ei_ubt46FbNA  1LMe5UqMS2ei_ubt46FbNA
# nClMzSME01CZn0MacQVl6w  nClMzSME01CZn0MacQVl6w
# pErXNL3l0GZiOIvGvgN0Hg  pErXNL3l0GZiOIvGvgN0Hg
#
#                                                                 alias  \
# GygGWp-ODQcqnizOxr5VLg                      postino-boulder-boulder-2
# PPFY_lw5KkPNfJwpI8dbbw                       king-dumpling-louisville
# _8vtC2Jo29HZwyNhQ3PWrg                    blackbelly-market-boulder-2
# mbrY3doqkZoNDjzLFfXnyQ  parma-trattoria-and-mozzarella-bar-louisville
# 1LMe5UqMS2ei_ubt46FbNA                    the-buff-restaurant-boulder
# nClMzSME01CZn0MacQVl6w                 south-side-walnut-cafe-boulder
# pErXNL3l0GZiOIvGvgN0Hg                     boulder-swim-club-no-title
#
#                                                     name  \
# GygGWp-ODQcqnizOxr5VLg                   Postino Boulder
# PPFY_lw5KkPNfJwpI8dbbw                     King Dumpling
# _8vtC2Jo29HZwyNhQ3PWrg                 Blackbelly Market
# mbrY3doqkZoNDjzLFfXnyQ  Parma Trattoria & Mozzarella Bar
# 1LMe5UqMS2ei_ubt46FbNA               The Buff Restaurant
# nClMzSME01CZn0MacQVl6w            South Side Walnut Cafe
# pErXNL3l0GZiOIvGvgN0Hg                 Boulder Swim Club
#
#                                                                 image_url  \
# GygGWp-ODQcqnizOxr5VLg  https://s3-media2.fl.yelpcdn.com/bphoto/qs98C8...
# PPFY_lw5KkPNfJwpI8dbbw  https://s3-media3.fl.yelpcdn.com/bphoto/BSjNo3...
# _8vtC2Jo29HZwyNhQ3PWrg  https://s3-media2.fl.yelpcdn.com/bphoto/R0Fcme...
# mbrY3doqkZoNDjzLFfXnyQ  https://s3-media4.fl.yelpcdn.com/bphoto/iFSEUe...
# 1LMe5UqMS2ei_ubt46FbNA  https://s3-media4.fl.yelpcdn.com/bphoto/Hll4hZ...
# nClMzSME01CZn0MacQVl6w  https://s3-media1.fl.yelpcdn.com/bphoto/P_0lYU...
# pErXNL3l0GZiOIvGvgN0Hg  https://s3-media2.fl.yelpcdn.com/bphoto/Ynkn_u...
#
#                                                                       url  \
# GygGWp-ODQcqnizOxr5VLg  https://www.yelp.com/biz/postino-boulder-bould...
# PPFY_lw5KkPNfJwpI8dbbw  https://www.yelp.com/biz/king-dumpling-louisvi...
# _8vtC2Jo29HZwyNhQ3PWrg  https://www.yelp.com/biz/blackbelly-market-bou...
# mbrY3doqkZoNDjzLFfXnyQ  https://www.yelp.com/biz/parma-trattoria-and-m...
# 1LMe5UqMS2ei_ubt46FbNA  https://www.yelp.com/biz/the-buff-restaurant-b...
# nClMzSME01CZn0MacQVl6w  https://www.yelp.com/biz/south-side-walnut-caf...
# pErXNL3l0GZiOIvGvgN0Hg  https://www.yelp.com/biz/boulder-swim-club-no-...
#
#                                phone   display_phone price
# GygGWp-ODQcqnizOxr5VLg  +13032853755  (303) 285-3755   NaN
# PPFY_lw5KkPNfJwpI8dbbw  +17207285903  (720) 728-5903   NaN
# _8vtC2Jo29HZwyNhQ3PWrg  +13032471000  (303) 247-1000    $$
# mbrY3doqkZoNDjzLFfXnyQ  +13032842741  (303) 284-2741    $$
# 1LMe5UqMS2ei_ubt46FbNA  +13034429150  (303) 442-9150    $$
# nClMzSME01CZn0MacQVl6w  +17203048118  (720) 304-8118    $$
# pErXNL3l0GZiOIvGvgN0Hg  +13034446444  (303) 444-6444   NaN

# %% [markdown]
# # Activity 2: pull restaurants in a different location
#
# - Try running a business search query for your hometown or another place by constructing a query similar to `yelp_genquery` but changing the location parameter
# - Other endpoints require feeding what's called the business' fusion id into the API. Take an id from `yelp_stronly.id` and use the documentation here to pull the reviews for that business: https://docs.developer.yelp.com/reference/v3_business_reviews
# - **Challenge**: generalize the previous step by writing a function that (1) takes a list of business ids as an input, (2) calls the reviews API for each id, (3) returns the results, and (4) rowbinds all results, i.e. turns them into a single, usable DataFrame

# %%
# your code here
selected_id = ' search'

# Construct the API request URL
api_url = f'https://api.yelp.com/v3/businesses/{selected_id}/reviews'

# Define your Yelp API key
api_key = 'hDmREkKL9dz5eDOpQ6AKykDFKpZDlfqKoRP6N9R6e4N3-35RRIcgoF7-HKfZbDiEOm6gPZueckvz6nE8o1bEEVdU2Qpo0M_SNvQ5IcEGiJGmCJ7PMTw5x0JY7q4zZnYx'

# Set up authentication headers
headers = {'Authorization': f'Bearer {api_key}'}

# Make the API request
response = requests.get(api_url, headers=headers)

# Check if the request was successful
if response.status_code == 200:
    # Extract and process the reviews data from the response
    reviews_data = response.json()
    # Process reviews_data as needed
    # Print or further analyze the reviews
    print(reviews_data)
else:
    print(f'Error: {response.status_code}')
# Out:
# Error: 400
